# %%
import raw_data_visualizer  as rv

# %%
data_folder = '../data/BCICIV_4_mat'

# %%
print("--- Running for Subject 1 with default parameters ---")
rv.explore_and_plot_bci_data(
    data_folder_path=data_folder, 
    subject_number=1,
    n_channels_to_plot=5,
    duration_to_plot=10,
    ecog_scaling=10000, 
    finger_to_plot_index=0,
    finger_plot_duration=60,
    finger_plot_start=0
)
# Out:
# --- Running for Subject 1 with default parameters ---
# Data loaded successfully from ../data/BCICIV_4_mat/sub1_comp.mat
#
# --- Data Structure Overview (from .mat file) ---
# Key: train_data, Type: <class 'numpy.ndarray'>, Shape: (400000, 62)
# Key: test_data, Type: <class 'numpy.ndarray'>, Shape: (200000, 62)
# Key: train_dg, Type: <class 'numpy.ndarray'>, Shape: (400000, 5)
#
# --- Data Parameters ---
# Sampling Frequency (sfreq): 1000 Hz
# Number of ECoG Channels (Subject 1): 62
# Number of Fingers (Dataglove): 5
# Train ECoG duration: 6.67 minutes
# Test ECoG duration: 3.33 minutes
# Creating RawArray with float64 data, n_channels=62, n_times=400000
#     Range : 0 ... 399999 =      0.000 ...   399.999 secs
# Ready.
#
# --- Visualizing Raw ECoG Data ---
# <MNEBrowseFigure size 1223x900 with 4 Axes>
# Effective window size : 2.048 (s)
# Plotting power spectral density (dB=True).
# ...

# %%
# Subject 2 
print("\n--- Running for Subject 2, Index Finger, 10 ECoG Channels ---")
rv.explore_and_plot_bci_data(
    data_folder_path=data_folder,
    subject_number=2,
    n_channels_to_plot=5,
    duration_to_plot=10,
    ecog_scaling=10000, 
    finger_to_plot_index=1,
    finger_plot_duration=60,
    finger_plot_start=0
)
# Out:
# --- Running for Subject 2, Index Finger, 10 ECoG Channels ---
# Data loaded successfully from ../data/BCICIV_4_mat/sub2_comp.mat
#
# --- Data Structure Overview (from .mat file) ---
# Key: train_data, Type: <class 'numpy.ndarray'>, Shape: (400000, 48)
# Key: test_data, Type: <class 'numpy.ndarray'>, Shape: (200000, 48)
# Key: train_dg, Type: <class 'numpy.ndarray'>, Shape: (400000, 5)
#
# --- Data Parameters ---
# Sampling Frequency (sfreq): 1000 Hz
# Number of ECoG Channels (Subject 2): 48
# Number of Fingers (Dataglove): 5
# Train ECoG duration: 6.67 minutes
# Test ECoG duration: 3.33 minutes
# Creating RawArray with float64 data, n_channels=48, n_times=400000
#     Range : 0 ... 399999 =      0.000 ...   399.999 secs
# Ready.
#
# --- Visualizing Raw ECoG Data ---
# <MNEBrowseFigure size 1223x900 with 4 Axes>
# Effective window size : 2.048 (s)
# Plotting power spectral density (dB=True).
# ...

# %%
# Subject 3 
print("\n--- Running for Subject 3, Ring Finger ---")
rv.explore_and_plot_bci_data(
    data_folder_path=data_folder,
    subject_number=3,
    n_channels_to_plot=5,
    duration_to_plot=10,
    ecog_scaling=10000,
    finger_to_plot_index=2,
    finger_plot_duration=60,
    finger_plot_start=0
)
# Out:
# --- Running for Subject 3, Ring Finger ---
# Data loaded successfully from ../data/BCICIV_4_mat/sub3_comp.mat
#
# --- Data Structure Overview (from .mat file) ---
# Key: train_data, Type: <class 'numpy.ndarray'>, Shape: (400000, 64)
# Key: test_data, Type: <class 'numpy.ndarray'>, Shape: (200000, 64)
# Key: train_dg, Type: <class 'numpy.ndarray'>, Shape: (400000, 5)
#
# --- Data Parameters ---
# Sampling Frequency (sfreq): 1000 Hz
# Number of ECoG Channels (Subject 3): 64
# Number of Fingers (Dataglove): 5
# Train ECoG duration: 6.67 minutes
# Test ECoG duration: 3.33 minutes
# Creating RawArray with float64 data, n_channels=64, n_times=400000
#     Range : 0 ... 399999 =      0.000 ...   399.999 secs
# Ready.
#
# --- Visualizing Raw ECoG Data ---
# <MNEBrowseFigure size 1223x900 with 4 Axes>
# Effective window size : 2.048 (s)
# Plotting power spectral density (dB=True).
# ...
